# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
x = [0, 1.5, 2]
y = [1, 3, 2]

# %%
f=CubicSpline(x,y,bc_type='natural')

# %%
x_new=np.linspace(0,2,100)

# %%
y_new=f(x_new)

# %%
plt.plot(x_new,y_new)
plt.plot(x, y, 'o', markersize=10)
plt.xlabel('x')
plt.ylabel('y')
plt.title('CubicSpline Tabel')
# Out:
# Text(0.5, 1.0, 'CubicSpline Tabel')

# %%
h=2
x0=1
y0=1


dy0=96
d2y0=120
d3y0=48

# %%
def fac(num):
    c=1
    f=1
    while(c<=num):
        f=f*c
        c+=1
    return f

# %%
def num_diff(x,x0,h,dy0,d2y0,d3y0):
    P=(x-x0)/h
    print(P)
    print(y0)
    return(y0+
           P*dy0+
           P*(P-1)/fac(2)*d2y0+
           P*(P-1)*(P-2)/fac(3)*d3y0)

# %%
num_diff(7.5,x0,h,dy0,d2y0,d3y0)
# Out:
# 3.25
# 1
# 824.875
